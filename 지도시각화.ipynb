# %%
import json
import sys

import geojson


for i in range(10,21):
    geo_path = './지도json/GD_NP_PG_'+str(i)+'.json'
    geo_json = json.load(open(geo_path, encoding='utf-8'))
    location_matrix = geo_json['http://lod.knps.or.kr/resource/GD_NP_PG_'+str(i)]['http://www.opengis.net/ont/geosparql#asWKT'][0]['value']
    location_matrix =location_matrix.replace('(','').replace(')','').replace('MULTIPOLYGON','')
    location_matrix = location_matrix.replace(',','').split(' ')
    for j in range(1,len(location_matrix),2):
        locations.append([float(location_matrix[j+1]),(float(location_matrix[j]))])

# %%
len(locations)
# Out:
# 140208

# %%
len(loaction_matrix)
# Out:
# 711128

# %%
locations = []

# %%
locations.append(geojson.Feature(geometry=geojson.MultiPoint(locations)))

# %%
result = geojson.GeometryCollection(locations)

# %%
json_data = geojson.dump(result, sys.stdout)
# Out:
# {"type": "GeometryCollection", "geometries": [[35.37456166565441, 127.672935413072], [35.37461446983629, 127.67291075789173], [35.37467160316844, 127.67286908497344], [35.37468206146868, 127.67285800640559], [35.374742485106495, 127.67279399904716], [35.37479737055299, 127.67273002404734], [35.3748713412814, 127.67266023031178], [35.3749139590029, 127.67262159930588], [35.37495968301161, 127.67257711236255], [35.375030569123936, 127.67249923883062], [35.37507944604119, 127.67242989848044], [35.37512664337961, 127.67237125602209], [35.375199772937094, 127.67231847127424], [35.375277463555655, 127.67226848414249], [35.37535794893311, 127.67218893799661], [35.37544891499044, 127.67211001765395], [35.375506061079776, 127.67205998244387], [35.37558152531953, 127.67197375722749], [35.375606713329574, 127.67192364765046], [35.375636640262684, 127.67176206440713], [35.375649847393824, 127.67170817087779], [35.375655581815934, 127.67168477073777], [35.375668810699246, 127.671625570294], [35.3
# ...

# %%
result
# Out:
# {"geometries": [[35.37456166565441, 127.672935413072], [35.37461446983629, 127.67291075789173], [35.37467160316844, 127.67286908497344], [35.37468206146868, 127.67285800640559], [35.374742485106495, 127.67279399904716], [35.37479737055299, 127.67273002404734], [35.3748713412814, 127.67266023031178], [35.3749139590029, 127.67262159930588], [35.37495968301161, 127.67257711236255], [35.375030569123936, 127.67249923883062], [35.37507944604119, 127.67242989848044], [35.37512664337961, 127.67237125602209], [35.375199772937094, 127.67231847127424], [35.375277463555655, 127.67226848414249], [35.37535794893311, 127.67218893799661], [35.37544891499044, 127.67211001765395], [35.375506061079776, 127.67205998244387], [35.37558152531953, 127.67197375722749], [35.375606713329574, 127.67192364765046], [35.375636640262684, 127.67176206440713], [35.375649847393824, 127.67170817087779], [35.375655581815934, 127.67168477073777], [35.375668810699246, 127.671625570294], [35.37568262397332, 127.67155035013
# ...

# %%
with open('geojson_test', 'w', encoding='utf-8') as make_file:
    json.dump(locations, make_file)

# %%
import folium
geo_path = 'C:\ex\창원\지도json\skorea-provinces-2018-geo.json'
map_osm = folium.Map(location=[37.566345, 126.977893])
rfile = open(geo_path, 'r', encoding='utf-8').read()
jsonData = json.loads(rfile)
folium.GeoJson(jsonData, name='json_data').add_to(map_osm)
map_osm.save('folium_kr.html')

# %%
import folium
map = folium.Map(location=[37.566345, 126.977893])
for i in range(0,len(locations)):
    folium.vector_layers.CircleMarker(
        location = locations[i],
        color = '#ff0000',radius=1).add_to(map)
for i in range(0,len(terminal_json)):
    folium.Marker(
        location = terminal_json[i]['location']).add_to(map)

map.save('test.html')

# %%
terminal_json = json.load(open('터미널위치정보.json', encoding='utf-8'))

# %%
terminal_json
# Out:
# [{'name': '서울남부터미널', 'location': ['37.484235', '127.01386']},
#  {'name': '센트럴시티터미널', 'location': ['37.504893', '127.001022']},
#  {'name': '서울고속버스터미널', 'location': ['37.5054076', '127.0048877']},
#  {'name': '상봉시외버스터미널', 'location': ['37.5960297', '127.0849694']},
#  {'name': '동서울종합터미널', 'location': ['37.534218', '127.091785']},
#  {'name': '전곡공용버스터미널', 'location': ['37.5342167', '127.0764158']},
#  {'name': '동두천터미널', 'location': ['37.880582', '127.049977']},
#  {'name': '포천시외버스터미널', 'location': ['37.8974852', '127.2013411']},
#  {'name': '운천시외버스터미널', 'location': ['38.090073', '127.271756']},
#  {'name': '가평시외버스터미널', 'location': ['37.7812404', '127.3977108']},
#  {'name': '문산버스터미널', 'location': ['37.8681767', '126.7186512']},
#  {'name': '금촌버스터미널', 'location': ['37.8681352', '126.7183077']},
#  {'name': '운정신도시버스터미널', 'location': ['37.867781', '126.5073077']},
#  {'name': '의정부시외버스터미널', 'location': ['37.7493547', '127.0525267']},
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
img = mpimg.imread("./둘레길지도/무등산 둘레길.png")
loc_pm = pd.read_excel("./버스정보/광주버스정류소위도경도.xlsx")

# %%
plt.imshow(img,extent=[126.864646,127.132167,35.081903,35.194757 ])

# %%
loc_pm.plot(kind="scatter", x="lon", y="lat",figsize=(20,10))
plt.imshow(img,extent=[126.904646,127.132167,35.081903,35.194757 ],aspect='auto')
plt.savefig('./무등산버스정류장.png',bbox_inches='tight')

# %%
loc_pm
# Out:
#       Unnamed: 0        lat         lon
# 0              0  35.221251  126.828321
# 1              1  35.218626  126.842110
# 2              2  35.269867  126.829406
# 3              3  35.175739  126.746690
# 4              4  35.276558  126.887278
# 5              5  35.171569  126.935633
# 6              6  35.244461  126.863722
# 7              7  35.019726  126.828486
# 8              8  35.149933  126.933181
# 9              9  35.187297  126.737239
# 10            10  35.175676  126.870679
# 11            11  35.136033  126.908536
# 12            12  35.058006  126.786517
# 13            13  35.239635  126.893679
# 14            14  35.240579  126.895318
# 15            15  35.147078  126.897550
# 16            16  35.069967  126.835138
# 17            17  35.158585  126.894939
# 18            18  35.226362  126.652144
# 19            19  35.246192  126.778478
# 20            20  35.131594  126.928761
# 21            21  35.188603  126.905242
# ...

# %%
loc_pm['lon'] = loc_pm['lon'].apply(float)

# %%
loc_pm2 =loc_pm[loc_pm['lon'] > 126.864646]
loc_pm3 =loc_pm2[loc_pm2['lon'] < 127.132167]
loc_pm4 =loc_pm3[loc_pm3['lat'] > 35.081903]
loc_pm5 =loc_pm4[loc_pm2['lat'] < 35.194757]

# %%
loc_pm3 =loc_pm2[loc_pm2['lon'] < 127.132167]

# %%
loc_pm4 =loc_pm3[loc_pm3['lat'] > 35.081903]

# %%
loc_pm5 =loc_pm4[loc_pm2['lat'] < 35.194757]
# Out:
# C:\Users\CPB06GameN\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
len(loc_pm5)
# Out:
# 1022

# %%
plt.savefig('./무등산버스정류장.png',bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
img = mpimg.imread("./둘레길지도/계룡산.png")
loc_pm = pd.read_excel("./버스정보/대전버스정류소위도경도.xlsx")

# %%
 loc_pm2 = loc_pm[loc_pm['lon'] > 127.164302]

# %%
loc_pm2 =loc_pm[loc_pm['lon'] > 127.164302]
loc_pm3 =loc_pm2[loc_pm2['lon'] < 127.328286]
loc_pm4 =loc_pm3[loc_pm3['lat'] > 36.293291]
loc_pm5 =loc_pm4[loc_pm2['lat'] < 36.401253]
# Out:
# C:\Users\CPB06GameN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
len(loc_pm5)
# Out:
# 901

# %%
loc_pm5.plot(kind="scatter", x="lon", y="lat",figsize=(20,10))
plt.imshow(img,extent=[127.164302,127.328286,36.293291,36.401253])
plt.savefig('./계룡산버스정류장.png',bbox_inches='tight')
